# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline
sns.set(color_codes=True)

# %%
#Importing Dataset
dataset = pd.read_csv('Automobile_data.csv')
print('Dataset first 5 rows head(5):\n',dataset.head(5))
print('Dataset last 5 rows tail(5):\n',dataset.tail(5))
print('Dataset column types:\n',dataset.dtypes)
# Out:
# Dataset first 5 rows head(5):
#     symboling  normalized-losses         make fuel-type aspiration  \
# 0          3                NaN  alfa-romero       gas        std
# 1          3                NaN  alfa-romero       gas        std
# 2          1                NaN  alfa-romero       gas        std
# 3          2              164.0         audi       gas        std
# 4          2              164.0         audi       gas        std
#
#   num-of-doors   body-style drive-wheels engine-location  wheel-base   ...     \
# 0          two  convertible          rwd           front        88.6   ...
# 1          two  convertible          rwd           front        88.6   ...
# 2          two    hatchback          rwd           front        94.5   ...
# 3         four        sedan          fwd           front        99.8   ...
# 4         four        sedan          4wd           front        99.4   ...
#
#    engine-size  fuel-system  bore  stroke compression-ratio horsepower  \
# 0          130         mpfi  3.47    2.68               9.0      111.0
# 1          130         mpfi  3.47    2.68               9.0      111.0
# 2          152         mpfi  2.68    3.47               9.0      154.0
# 3          109         mpfi  3.19    3.40              10.0      102.0
# 4          136         mpfi  3.19    3.40               8.0      115.0
#
#    peak-rpm city-mpg  highway-mpg    price
# 0    5000.0       21           27  13495.0
# 1    5000.0       21           27  16500.0
# 2    5000.0       19           26  16500.0
# 3    5500.0       24           30  13950.0
# 4    5500.0       18           22  17450.0
#
# [5 rows x 26 columns]
# Dataset last 5 rows tail(5):
#       symboling  normalized-losses   make fuel-type aspiration num-of-doors  \
# 200         -1               95.0  volvo       gas        std         four
# 201         -1               95.0  volvo       gas      turbo         four
# 202         -1               95.0  volvo       gas        std         four
# 203         -1               95.0  volvo    diesel      turbo         four
# 204         -1               95.0  volvo       gas      turbo         four
#
#     body-style drive-wheels engine-location  wheel-base   ...     engine-size  \
# 200      sedan          rwd           front       109.1   ...             141
# 201      sedan          rwd           front       109.1   ...             141
# 202      sedan          rwd           front       109.1   ...             173
# 203      sedan          rwd           front       109.1   ...             145
# 204      sedan          rwd           front       109.1   ...             141
#
#      fuel-system  bore  stroke compression-ratio horsepower  peak-rpm  \
# 200         mpfi  3.78    3.15               9.5      114.0    5400.0
# 201         mpfi  3.78    3.15               8.7      160.0    5300.0
# 202         mpfi  3.58    2.87               8.8      134.0    5500.0
# 203          idi  3.01    3.40              23.0      106.0    4800.0
# 204         mpfi  3.78    3.15               9.5      114.0    5400.0
#
#     city-mpg  highway-mpg    price
# 200       23           28  16845.0
# 201       19           25  19045.0
# 202       18           23  21485.0
# 203       26           27  22470.0
# 204       19           25  22625.0
#
# [5 rows x 26 columns]
# Dataset column types:
#  symboling              int64
# normalized-losses    float64
# make                  object
# fuel-type             object
# aspiration            object
# num-of-doors          object
# body-style            object
# drive-wheels          object
# engine-location       object
# wheel-base           float64
# length               float64
# width                float64
# height               float64
# curb-weight            int64
# engine-type           object
# num-of-cylinders      object
# engine-size            int64
# fuel-system           object
# bore                 float64
# stroke               float64
# compression-ratio    float64
# horsepower           float64
# peak-rpm             float64
# city-mpg               int64
# highway-mpg            int64
# price                float64
# dtype: object

# %%
#Removing uncessary columns from dataset
dataset.drop(['num-of-doors','symboling','curb-weight','compression-ratio'],axis='columns',inplace=True)
dataset.head(2)
# Out:
#    normalized-losses         make fuel-type aspiration   body-style  \
# 0                NaN  alfa-romero       gas        std  convertible
# 1                NaN  alfa-romero       gas        std  convertible
#
#   drive-wheels engine-location  wheel-base  length  width   ...     \
# 0          rwd           front        88.6   168.8   64.1   ...
# 1          rwd           front        88.6   168.8   64.1   ...
#
#    num-of-cylinders engine-size fuel-system  bore stroke  horsepower  \
# 0              four         130        mpfi  3.47   2.68       111.0
# 1              four         130        mpfi  3.47   2.68       111.0
#
#    peak-rpm  city-mpg  highway-mpg    price
# 0    5000.0        21           27  13495.0
# 1    5000.0        21           27  16500.0
#
# [2 rows x 22 columns]

# %%
#Renaming columns
dataset = dataset.rename(columns={"city-mpg":"city mileage(mpg)","highway-mpg":"highway mileage(mpg)"})
dataset.head(2)
# Out:
#    normalized-losses         make fuel-type aspiration   body-style  \
# 0                NaN  alfa-romero       gas        std  convertible
# 1                NaN  alfa-romero       gas        std  convertible
#
#   drive-wheels engine-location  wheel-base  length  width   ...     \
# 0          rwd           front        88.6   168.8   64.1   ...
# 1          rwd           front        88.6   168.8   64.1   ...
#
#    num-of-cylinders engine-size fuel-system  bore stroke  horsepower  \
# 0              four         130        mpfi  3.47   2.68       111.0
# 1              four         130        mpfi  3.47   2.68       111.0
#
#    peak-rpm  city mileage(mpg)  highway mileage(mpg)    price
# 0    5000.0                 21                    27  13495.0
# 1    5000.0                 21                    27  16500.0
#
# [2 rows x 22 columns]

# %%
#Dropping duplicate rows
dataset.shape
duplicate_rows_df = dataset[dataset.duplicated()]
print("number of duplicate rows: ", duplicate_rows_df.shape)
print("Duplicate row:\n",duplicate_rows_df)
print("rows count",dataset.count())
dataset = dataset.drop_duplicates()
dataset.head(5)
# Out:
# number of duplicate rows:  (1, 22)
# Duplicate row:
#      normalized-losses   make fuel-type aspiration body-style drive-wheels  \
# 45                NaN  isuzu       gas        std      sedan          fwd
#
#    engine-location  wheel-base  length  width  ...    num-of-cylinders  \
# 45           front        94.5   155.9   63.6  ...                four
#
#    engine-size fuel-system  bore stroke  horsepower  peak-rpm  \
# 45          90        2bbl  3.03   3.11        70.0    5400.0
#
#     city mileage(mpg)  highway mileage(mpg)  price
# 45                 38                    43    NaN
#
# [1 rows x 22 columns]
# rows count normalized-losses       164
# make                    205
# fuel-type               205
# aspiration              205
# body-style              205
# drive-wheels            205
# engine-location         205
# wheel-base              205
# length                  205
# width                   205
# height                  205
# engine-type             205
# num-of-cylinders        205
# engine-size             205
# fuel-system             205
# bore                    201
# stroke                  201
# horsepower              203
# peak-rpm                203
# city mileage(mpg)       205
# highway mileage(mpg)    205
# price                   201
# dtype: int64
#    normalized-losses         make fuel-type aspiration   body-style  \
# 0                NaN  alfa-romero       gas        std  convertible
# 1                NaN  alfa-romero       gas        std  convertible
# 2                NaN  alfa-romero       gas        std    hatchback
# 3              164.0         audi       gas        std        sedan
# 4              164.0         audi       gas        std        sedan
#
#   drive-wheels engine-location  wheel-base  length  width   ...     \
# 0          rwd           front        88.6   168.8   64.1   ...
# 1          rwd           front        88.6   168.8   64.1   ...
# 2          rwd           front        94.5   171.2   65.5   ...
# 3          fwd           front        99.8   176.6   66.2   ...
# 4          4wd           front        99.4   176.6   66.4   ...
#
#    num-of-cylinders engine-size fuel-system  bore stroke  horsepower  \
# 0              four         130        mpfi  3.47   2.68       111.0
# 1              four         130        mpfi  3.47   2.68       111.0
# 2               six         152        mpfi  2.68   3.47       154.0
# 3              four         109        mpfi  3.19   3.40       102.0
# 4              five         136        mpfi  3.19   3.40       115.0
#
#    peak-rpm  city mileage(mpg)  highway mileage(mpg)    price
# 0    5000.0                 21                    27  13495.0
# 1    5000.0                 21                    27  16500.0
# 2    5000.0                 19                    26  16500.0
# 3    5500.0                 24                    30  13950.0
# 4    5500.0                 18                    22  17450.0
#
# [5 rows x 22 columns]

# %%
print('Checking dataset containing null values:\n',dataset.isnull().sum())
# Out:
# Checking dataset containing null values:
#  normalized-losses       41
# make                     0
# fuel-type                0
# aspiration               0
# body-style               0
# drive-wheels             0
# engine-location          0
# wheel-base               0
# length                   0
# width                    0
# height                   0
# engine-type              0
# num-of-cylinders         0
# engine-size              0
# fuel-system              0
# bore                     4
# stroke                   4
# horsepower               2
# peak-rpm                 2
# city mileage(mpg)        0
# highway mileage(mpg)     0
# price                    4
# dtype: int64

# %%
#Fill drop,stroke,horsepower nan values with mean
dataset['bore'] = dataset['bore'].fillna(dataset['bore'].mean())
dataset['stroke'] = dataset['stroke'].fillna(dataset['stroke'].mean())
dataset['horsepower'] = dataset['horsepower'].fillna(dataset['horsepower'].mean())
dataset['normalized-losses'] = dataset['normalized-losses'].fillna(dataset['normalized-losses'].mean())
dataset['peak-rpm'] = dataset['peak-rpm'].fillna(dataset['peak-rpm'].mean())
dataset['price'] = dataset['price'].fillna(dataset['price'].mean())
print('Checking nan values count again:\n',dataset.isnull().sum())
#no nan values
# Out:
# Checking nan values count again:
#  normalized-losses       0
# make                    0
# fuel-type               0
# aspiration              0
# body-style              0
# drive-wheels            0
# engine-location         0
# wheel-base              0
# length                  0
# width                   0
# height                  0
# engine-type             0
# num-of-cylinders        0
# engine-size             0
# fuel-system             0
# bore                    0
# stroke                  0
# horsepower              0
# peak-rpm                0
# city mileage(mpg)       0
# highway mileage(mpg)    0
# price                   0
# dtype: int64

# %%
#detecting outliers
sns.boxplot(x=dataset['price'])

# %%
#detecting outliers
sns.boxplot(x=dataset['peak-rpm'])

# %%
#detecting outliers
sns.boxplot(x=dataset['city mileage(mpg)'])

# %%
#detecting outliers
sns.boxplot(x=dataset['highway mileage(mpg)'])

# %%
#Intrer quantile range
Q1 = dataset.quantile(0.25)
Q3 = dataset.quantile(0.75)
iqr = Q3-Q1
print(iqr)
# Out:
# normalized-losses         36.00
# wheel-base                 7.90
# length                    16.80
# width                      2.80
# height                     3.50
# engine-size               44.00
# bore                       0.43
# stroke                     0.30
# horsepower                46.00
# peak-rpm                 700.00
# city mileage(mpg)         11.00
# highway mileage(mpg)       9.00
# price                   8712.00
# dtype: float64

# %%
# Plotting a Histogram
dataset.make.value_counts().nlargest(40).plot(kind='bar', figsize=(10,5))
plt.title("Number of cars by make")
plt.ylabel('Number of cars')
plt.xlabel('Make');

# %%
# Finding the relations between the variables.
plt.figure(figsize=(20,10))
c= dataset.corr()
sns.heatmap(c,cmap="BrBG",annot=True)
c
# Out:
#                       normalized-losses  wheel-base    length     width  \
# normalized-losses              1.000000   -0.056588  0.019312  0.084436
# wheel-base                    -0.056588    1.000000  0.875215  0.794642
# length                         0.019312    0.875215  1.000000  0.840198
# width                          0.084436    0.794642  0.840198  1.000000
# height                        -0.371162    0.588423  0.489126  0.276598
# engine-size                    0.111212    0.568041  0.681895  0.734251
# bore                          -0.029258    0.486913  0.603435  0.556541
# stroke                         0.054998    0.159584  0.126887  0.181090
# horsepower                     0.203811    0.349999  0.552138  0.640626
# peak-rpm                       0.237942   -0.359422 -0.284622 -0.217615
# city mileage(mpg)             -0.220834   -0.468609 -0.666576 -0.640208
# highway mileage(mpg)          -0.179626   -0.542798 -0.700973 -0.674984
# price                          0.133999    0.583887  0.686656  0.730785
#
#                         height  engine-size      bore    stroke  horsepower  \
# normalized-losses    -0.371162     0.111212 -0.029258  0.054998    0.203811
# wheel-base            0.588423     0.568041  0.486913  0.159584    0.349999
# length                0.489126     0.681895  0.603435  0.126887    0.552138
# width                 0.276598     0.734251  0.556541  0.181090    0.640626
# height                1.000000     0.064270  0.167782 -0.057141   -0.113516
# engine-size           0.064270     1.000000  0.581705  0.201507    0.809999
# bore                  0.167782     0.581705  1.000000 -0.058646    0.573839
# stroke               -0.057141     0.201507 -0.058646  1.000000    0.086582
# horsepower           -0.113516     0.809999  0.573839  0.086582    1.000000
# peak-rpm             -0.319242    -0.242757 -0.252405 -0.065591    0.133786
# city mileage(mpg)    -0.042298    -0.652544 -0.581227 -0.038155   -0.803902
# highway mileage(mpg) -0.102096    -0.676294 -0.583732 -0.040285   -0.770752
# price                 0.134553     0.863424  0.533911  0.082138    0.759304
#
#                       peak-rpm  city mileage(mpg)  highway mileage(mpg)  \
# normalized-losses     0.237942          -0.220834             -0.179626
# wheel-base           -0.359422          -0.468609             -0.542798
# length               -0.284622          -0.666576             -0.700973
# width                -0.217615          -0.640208             -0.674984
# height               -0.319242          -0.042298             -0.102096
# engine-size          -0.242757          -0.652544             -0.676294
# bore                 -0.252405          -0.581227             -0.583732
# stroke               -0.065591          -0.038155             -0.040285
# horsepower            0.133786          -0.803902             -0.770752
# peak-rpm              1.000000          -0.120490             -0.059819
# city mileage(mpg)    -0.120490           1.000000              0.970914
# highway mileage(mpg) -0.059819           0.970914              1.000000
# price                -0.100924          -0.673813             -0.695970
#
#                          price
# normalized-losses     0.133999
# wheel-base            0.583887
# length                0.686656
# width                 0.730785
# height                0.134553
# engine-size           0.863424
# bore                  0.533911
# stroke                0.082138
# horsepower            0.759304
# peak-rpm             -0.100924
# city mileage(mpg)    -0.673813
# highway mileage(mpg) -0.695970
# price                 1.000000

# %%
# Plotting a scatter plot
fig, ax = plt.subplots(figsize=(10,6))
ax.scatter(dataset['horsepower'], dataset['price'])
ax.set_xlabel('Horsepower')
ax.set_ylabel('Price')
plt.show()
